# %% [markdown]
# <a href="https://colab.research.google.com/github/Vishu6744/RL/blob/main/RL_Vishu_Practical2_(part_1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
#10 random integers between 0 and 50
x=np.random.randint(0,50,1000)

# %%
print(x)
# Out:
# [ 0  1 48  8 10 35 23 30 34 17 31 30 24  7 30 16  6 39 49  8 48  8 32 42
#  40 34 30 40 46 31  2 39  0 33 24 43 13 17 34 24 12 44 33 18 19  3 16 11
#  48 13 41 40  3 24 23 23  6 25 41 15 36 10 10 32 44 47 27 25 32  0  0 23
#  37 26 38 11 20  0 37 38 32 11  2 28 13 35 27 47 30 14 29 39 33 40 43  9
#  29 13  2  8  2  5 47 10 43 15 22 27 26 38 41 28  4  7 38 45 32 49 30 33
#  23  6 10 37  8 14 12 42 26 21 10  1 41 40 14 11  9 18 48 18 37 18 20 28
#  27 14 22  2 13 24 40 26  2 42 25 34 26 23 44 42  8 46 42 12  2 19 11  9
#  20 22 37 23 23 27 19 32 10 38 28 17  2 13 18 38  2 48 44 38 35 18  7  3
#  17 43 40 18 32  7 35 38  9 14 15 17 13 27 37 26  3 28 41 47  0 37 22 11
#  22 35 30 24 38 27 41 23  2 22 43 46 19 45 44  1 29 39  6 19 15  7 14 42
#   2 39 15  6 11 42 37 29 30 26 12 10  8  2 48 30 18 40  8 21 11 19 36 41
#  12 21 40  9 21 41  5 44 19 17  3 31 10 20 35  4 48  1 24 23 47 10  8 36
#   5 19 32 10 14  5 21 32 41 12 39  7 21 34 24 22 33 22  0 30 43 46 35  9
# ...

# %%
y=x+np.random.randint(0,10,1000)

# %%
print(y)
# Out:
# [ 7  4 53 13 15 37 31 37 37 18 36 31 28 13 35 16 10 43 52 15 51 13 33 50
#  44 42 35 44 46 33  5 44  6 38 25 45 17 24 40 31 19 44 33 21 26  5 23 15
#  54 13 50 45  5 28 26 28 12 28 49 15 39 18 19 32 49 51 31 26 34  0  0 31
#  40 30 38 20 25  8 46 42 35 17  3 31 22 43 32 52 32 17 33 48 38 46 50 12
#  34 14  3 14 11  5 48 10 46 23 30 29 33 40 45 36  7  7 40 45 41 55 35 41
#  27  8 12 41 11 15 16 49 27 22 10  7 47 43 18 18 15 19 56 20 39 21 22 29
#  35 14 24 10 16 33 41 29  3 45 25 35 32 31 52 43 10 48 44 15  5 23 18  9
#  23 31 41 25 24 34 22 37 11 45 28 26 10 21 22 41  2 52 46 39 36 23 14  4
#  23 43 40 20 34 13 38 38 11 15 18 24 13 27 46 33  9 35 47 49  0 44 27 19
#  24 38 33 25 44 30 48 26  3 30 47 51 20 49 44  4 38 46  8 24 22 16 23 43
#   2 39 22 15 19 48 37 29 36 33 17 17  9  5 51 39 24 44  9 26 12 22 44 45
#  21 23 40  9 24 45  5 52 22 21  5 36 16 20 37 11 52  1 27 26 54 17  8 44
#   5 22 33 18 14  7 25 33 44 17 46  8 22 36 29 30 39 23  4 34 51 55 44 14
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')

plt.scatter(x,y)
plt.show()

# %%
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.98123045],
#        [0.98123045, 1.        ]])

# %%
z=100-x

# %%
np.corrcoef(x,z)
# Out:
# array([[ 1., -1.],
#        [-1.,  1.]])

# %%
plt.scatter(x,z)
plt.show()

# %%
p=np.random.randint(0,50,1000)

# %%
np.corrcoef(x,p)
# Out:
# array([[1.        , 0.01643321],
#        [0.01643321, 1.        ]])

# %%
plt.scatter(x,p)
plt.show()

# %%
import pandas as pd
df=pd.DataFrame({'a':np.random.randint(0,50,1000)})
df['b']=df['a']+np.random.normal(0,10,1000)
df['c']=100-df['a']+np.random.normal(0,5,1000)
df['d']=np.random.normal(0,50,1000)

# %%
df.corr()
# Out:
#           a         b         c         d
# a  1.000000  0.805494 -0.945318  0.019284
# b  0.805494  1.000000 -0.763275  0.013453
# c -0.945318 -0.763275  1.000000 -0.030836
# d  0.019284  0.013453 -0.030836  1.000000

# %%
pd.plotting.scatter_matrix(df, figsize=(6,6))
plt.show()

# %%
plt.matshow(df.corr())
plt.xticks(range(len(df.columns)),df.columns)
plt.yticks(range(len(df.columns)),df.columns)
plt.colorbar()
plt.show()
